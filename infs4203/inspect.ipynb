# %%
from utils import get_data_dir
import pandas as pd
from dataset import INFS4203Dataset

dset1 = INFS4203Dataset("train.csv", preprocessing=True)
dset2 = INFS4203Dataset("train2.csv", preprocessing=True)
joint_dset = INFS4203Dataset("train_strat.csv", preprocessing=True)

# %%
dset1.plotTSNE(dset1.df)
dset2.plotTSNE(dset2.df)
# Out:
# /Users/larsmoan/Documents/UQ/INFS4203/infs4203/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/larsmoan/Documents/UQ/INFS4203/infs4203/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/larsmoan/Documents/UQ/INFS4203/infs4203/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
joint_dset.plotTSNE(joint_dset.df)
# Out:
# /Users/larsmoan/Documents/UQ/INFS4203/infs4203/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/larsmoan/Documents/UQ/INFS4203/infs4203/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/larsmoan/Documents/UQ/INFS4203/infs4203/.venv/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
joint_dset.shapiro_wilk()
dset1.shapiro_wilk()
dset2.shapiro_wilk()
# Out:
# /Users/larsmoan/Documents/UQ/INFS4203/infs4203/.venv/lib/python3.11/site-packages/scipy/stats/_morestats.py:1797: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
